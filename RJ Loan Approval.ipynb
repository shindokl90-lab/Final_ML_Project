# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import datetime as dt


file_accepted = "accepted_2007_to_2018Q4.csv"

# Read Purchasing File and store into Pandas data frame
acc_data = pd.read_csv(file_accepted)
# Out:
# /Users/ratna/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
acc_data
# Out:
#                                                        id  member_id  \
# 0                                                68407277        NaN
# 1                                                68355089        NaN
# 2                                                68341763        NaN
# 3                                                66310712        NaN
# 4                                                68476807        NaN
# ...                                                   ...        ...
# 2260696                                          88985880        NaN
# 2260697                                          88224441        NaN
# 2260698                                          88215728        NaN
# 2260699  Total amount funded in policy code 1: 1465324575        NaN
# 2260700   Total amount funded in policy code 2: 521953170        NaN
#
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# ...

# %%
for col in acc_data.columns:
    print (col)
# Out:
# id
# member_id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# ...

# %%
columnpDatatype = acc_data.dtypes['issue_d']
print(columnpDatatype)
# Out:
# object

# %%
loans_df = acc_data[['id','loan_amnt', 'funded_amnt', 'funded_amnt_inv, 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'purpose', 'addr_state', 'dti', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'hardship_flag', 'pub_rec_bankruptcies','tax_liens', 'disbursement_method', 'debt_settlement_flag']]
loans_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-7e1c57ba23a9> in <module>
# ----> 1 loans_df = acc_data[['id','loan_amnt', 'funded_amnt', 'funded_amnt_inv,''term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'purpose', 'addr_state', 'dti', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'hardship_flag', 'pub_rec_bankruptcies','tax_liens', 'disbursement_method', 'debt_settlement_flag']]
#       2 loans_df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# ...
